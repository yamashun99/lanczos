# %%
from utils import *

# %%
A = get_random_hermite_matrix(10000)
print(A)
# Out:
# [[0.0553289  0.47961505 0.5519522  ... 0.8409824  0.80837659 0.64340957]
#  [0.47961505 0.82354444 0.5639361  ... 0.30360026 0.53671298 0.84690258]
#  [0.5519522  0.5639361  0.3349215  ... 0.8033079  0.34586378 0.87192885]
#  ...
#  [0.8409824  0.30360026 0.8033079  ... 0.12350579 0.8949037  0.31236454]
#  [0.80837659 0.53671298 0.34586378 ... 0.8949037  0.32059064 0.88642619]
#  [0.64340957 0.84690258 0.87192885 ... 0.31236454 0.88642619 0.41796331]]

# %%
v10, lambda_k = power_iteration(A, 10)
print(v10, lambda_k[-1])
# Out:
# [0.0100753  0.00996102 0.00998713 ... 0.00997188 0.01002516 0.01002118] 4999.545329096236

# %%
lambda_k = np.array(lambda_k)
err = lambda_k[1:] - lambda_k[:-1]
print(err)
# Out:
# [ 2.78953329e-02  9.33248884e-07  3.45607987e-11 -7.27595761e-12
#   3.63797881e-12 -9.09494702e-13  0.00000000e+00  9.09494702e-13
#   0.00000000e+00]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(lambda_k, 'o-')
ax2 = ax.twinx()
ax2.plot(err, 'o-', color='r')
ax2.semilogy()
# Out:
# []

# %%
e, v =np.linalg.eigh(A)

# %%
e
# Out:
# array([-3.86450506e+00, -3.81169291e+00, -3.73494468e+00, -3.50722774e+00,
#        -3.34418395e+00, -3.19436210e+00, -3.13757965e+00, -2.99150201e+00,
#        -2.92040164e+00, -2.81388303e+00, -2.69943014e+00, -2.63373827e+00,
#        -2.58054739e+00, -2.45454059e+00, -2.42627689e+00, -2.38245446e+00,
#        -2.32572621e+00, -2.24494113e+00, -2.09044108e+00, -2.03430907e+00,
#        -1.87082539e+00, -1.84896506e+00, -1.80422414e+00, -1.78703496e+00,
#        -1.68097472e+00, -1.62922331e+00, -1.59043674e+00, -1.51789260e+00,
#        -1.46684261e+00, -1.36015449e+00, -1.25673936e+00, -1.13069022e+00,
#        -1.02844142e+00, -1.00563233e+00, -9.58596589e-01, -9.19258404e-01,
#        -8.59268270e-01, -7.96832191e-01, -7.76331653e-01, -7.60370143e-01,
#        -6.61113804e-01, -6.10910555e-01, -5.12433535e-01, -4.86150985e-01,
#        -4.02294628e-01, -3.53071677e-01, -2.81809709e-01, -2.27316821e-01,
# ...
